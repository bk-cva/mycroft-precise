# %%
import os
from numpy import save

import tensorflow as tf
import keras
from precise.model import load_precise_model
# Out:
# Using TensorFlow backend.

# %%
MODEL_ROOT_PATH = './models'
MODEL_DIR = 'hey-sunshine'
model_file = os.path.join(MODEL_ROOT_PATH, MODEL_DIR, 'hey_sunshine.net')
print(model_file)
# Out:
# ./models/hey-sunshine/hey_sunshine.net

# %%
model = load_precise_model(model_file)
# Out:
# WARNING:tensorflow:From /home/nguyenminh/.local/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/nguyenminh/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
config = model.get_config()
print(config)
print(len(config['layers']))
# Out:
# {'name': 'sequential_1', 'layers': [{'class_name': 'GRU', 'config': {'name': 'net', 'trainable': True, 'batch_input_shape': (None, 29, 13), 'dtype': 'float32', 'return_sequences': False, 'return_state': False, 'go_backwards': False, 'stateful': False, 'unroll': False, 'units': 20, 'activation': 'linear', 'recurrent_activation': 'hard_sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'recurrent_initializer': {'class_name': 'Orthogonal', 'config': {'gain': 1.0, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'recurrent_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'recurrent_constraint': None, 'bias_constraint': None, 'dropout': 0.2, 'recurrent_dropout': 0.0, 'implementation': 1, 'reset_after': False}}, {'class_name': 'Dense', 'config': {'name': 'dense_1', 'trainable': True, 'units': 1, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1.0, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}}]}
# 2

# %%
weights = model.get_weights()
len(weights)
# Out:
# 5

# %%
for i, w in enumerate(weights):
    print(i)
    print(w.shape)
    print('-------------------')
# Out:
# 0
# (13, 60)
# -------------------
# 1
# (20, 60)
# -------------------
# 2
# (60,)
# -------------------
# 3
# (20, 1)
# -------------------
# 4
# (1,)
# -------------------

# %%
from contextlib import redirect_stdout

with open('architect.txt', 'w') as f:
    with redirect_stdout(f):
        model.summary()

# %%
MODEL_WEIGHTS_PATH = os.path.join('./model-weights', 'hey-sunshine')
os.makedirs(MODEL_WEIGHTS_PATH, exist_ok=True)

# %%
save(os.path.join(MODEL_WEIGHTS_PATH, 'kernel_1'), weights[0])
save(os.path.join(MODEL_WEIGHTS_PATH, 'recurrent_1'), weights[1])
save(os.path.join(MODEL_WEIGHTS_PATH, 'bias_1'), weights[2])
# save(os.path.join(MODEL_WEIGHTS_PATH, 'kernel_2'), weights[3])
# save(os.path.join(MODEL_WEIGHTS_PATH, 'recurrent_2'), weights[4])
# save(os.path.join(MODEL_WEIGHTS_PATH, 'bias_2'), weights[5])
save(os.path.join(MODEL_WEIGHTS_PATH, 'h2'), weights[3])
save(os.path.join(MODEL_WEIGHTS_PATH, 'b2'), weights[4])

# %%
from tensorflow.python.platform import gfile
GRAPH_PB_PATH = './precise-data/hey-mycroft-gru/hey-mycroft.gru.pb'
with tf.Session() as sess:
   print("load graph")
   with gfile.FastGFile(GRAPH_PB_PATH,'rb') as f:
       graph_def = tf.GraphDef()
   graph_def.ParseFromString(f.read())
   sess.graph.as_default()
   tf.import_graph_def(graph_def, name='')
   graph_nodes=[n for n in graph_def.node]
   names = []
   for t in graph_nodes:
      names.append(t.name)
    
   print('name: ', names)
# Out:
# load graph
# WARNING:tensorflow:From <ipython-input-25-d99cab92fdef>:5: FastGFile.__init__ (from tensorflow.python.platform.gfile) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.gfile.GFile
ul_1', 'net/while/MatMul_1/Enter', 'net/while/MatMul_2', 'net/while/MatMul_2/Enter', 'net/while/BiasAdd', 'net/while/BiasAdd/Enter', 'net/while/BiasAdd_1', 'net/while/BiasAdd_1/Enter', 'net/while/BiasAdd_2', 'net/while/BiasAdd_2/Enter', 'net/while/MatMul_3', 'net/while/MatMul_3/Enter', 'net/while/MatMul_4', 'net/while/MatMul_4/Enter', 'net/while/add_1', 'net/while/mul_3/x', 'net/while/mul_3', 'net/while/add_2/y', 'net/while/add_2', 'net/while/Const', 'net/while/Const_1', 'net/while/clip_by_value', 'net/while/add_3', 'net/while/mul_4/x', 'net/while/mul_4', 'net/while/add_4/y', 'net/while/add_4', 'net/while/Const_2', 'net/while/Const_3', 'net/while/clip_by_value_1', 'net/while/mul_5', 'net/while/MatMul_5', 'net/while/MatMul_5/Enter', 'net/while/add_5', 'net/while/mul_6', 'net/while/sub/x', 'net/while/sub', 'net/while/mul_7', 'net/while/add_6', 'net/while/TensorArrayWrite/TensorArrayWriteV3', 'net/while/TensorArrayWrite/TensorArrayWriteV3/Enter', 'net/while/add_7/y', 'net/while/add_7', 'net/while/NextIteration', 'net/while/NextIteration_1', 'net/while/NextIteration_2', 'net/while/NextIterat ...

# %%
wts = [n for n in graph_nodes if n.op=='Const']

# %%
wts
# Out:
# [name: "net/kernel"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#          dim {
#            size: 13
#          }
#          dim {
#            size: 60
#          }
#        }
#        tensor_content: "~\261\302\274\213\201\220\275\211\017\366\275*h\370\274\016#\212\275A\"/\275\030;\214=L.\270\273\222\204\234<&8A\275\365\357\364<+,\237\2754\211\273<_x1\273\276\277\036<\237\356\203=\272\021\235\274aL\226\275\020>\270\275\312\025\221\274B?\247\274\377\220->\231\214,\275\204\2525\276O\255)\276I\224\232\276P\234\247=\004\373\224\274\227\317)\275G\n\267\275\323Dj>\"\'\243\275\341z=<>t&?\351\014\322\274\343\253\326;\021\0305=\266\325\r>\266\354\261\275\257\020\350\275D\376\235>B<\020>\300\023N\276\312\217I>\376+\004\275\247\203\326\275JN\245\276\330\320\007\275\006P\000?\024\265\025<\273\352\211=\273\237|\276\264\222O\276!,7=%{\003?m\022\r\275\016f\345>\275\351\020>16F\276KU\023\276\000\027\210\274\306\007\265\274~\206\014\275\336^\367\274\024\275$\275%;\225\275\027-\021=\2426u\275\360c\3559\031~\t\275pi\016\274L\032)\275\316)\263<\230\310\211\273\001\333u=*\003\024\275\203\\\233\274\302t\240;\204:\317\275\252\t\253<hC\3609\202\240\001>\\ \006\275\274n\211<R\262A\275\364\335\023<\350i\320<\263Q_\275\232M\004\275\3131|\275\256?\235=\373j9\275\255\253.=\216?\355\2740\0326= \"F=\017n3=8\261\201=G\237\033\275\024\031\265\275&\253\337;\275\212\324\2752\272\335\274d\321\022>\366\336\014\276\342\2211\276!p\370\275A\240n\276\211%\310\275\273\352\017<{\000c=\377\363\224;\237\255\037\276*\2502\274w\200\007>\274\'%>\244\365\360=\013

#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\001\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_1/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000\000\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_1/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000\024\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_1/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\001\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_2/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000\024\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_2/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000(\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_2/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\001\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_3/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000\024\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_3/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000(\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_3/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\001\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_4/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000(\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_4/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000\000\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_4/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\001\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_5/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000(\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_5/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\000\000\000\000\000\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_5/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\001\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_6/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/strided_slice_6/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 20
#      }
#    }
#  },
#  name: "net/strided_slice_6/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/strided_slice_7/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 20
#      }
#    }
#  },
#  name: "net/strided_slice_7/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 40
#      }
#    }
#  },
#  name: "net/strided_slice_7/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/strided_slice_8/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 40
#      }
#    }
#  },
#  name: "net/strided_slice_8/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/strided_slice_8/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/Sum/reduction_indices"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\002\000\000\000"
#      }
#    }
#  },
#  name: "net/ExpandDims/dim"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: -1
#      }
#    }
#  },
#  name: "net/Tile/multiples"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 2
#          }
#        }
#        tensor_content: "\001\000\000\000\024\000\000\000"
#      }
#    }
#  },
#  name: "net/transpose/perm"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 3
#          }
#        }
#        tensor_content: "\001\000\000\000\000\000\000\000\002\000\000\000"
#      }
#    }
#  },
#  name: "net/strided_slice_9/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/strided_slice_9/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/strided_slice_9/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/strided_slice_10/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/strided_slice_10/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/strided_slice_10/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/ones_like/Const"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 1.0
#      }
#    }
#  },
#  name: "net/TensorArrayUnstack/strided_slice/stack"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/TensorArrayUnstack/strided_slice/stack_1"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/TensorArrayUnstack/strided_slice/stack_2"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/TensorArrayUnstack/range/start"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/TensorArrayUnstack/range/delta"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/time"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/while/maximum_iterations"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 29
#      }
#    }
#  },
#  name: "net/while/iteration_counter"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 0
#      }
#    }
#  },
#  name: "net/while/add/y"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/while/mul_3/x"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 0.20000000298023224
#      }
#    }
#  },
#  name: "net/while/add_2/y"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 0.5
#      }
#    }
#  },
#  name: "net/while/Const"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 0.0
#      }
#    }
#  },
#  name: "net/while/Const_1"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 1.0
#      }
#    }
#  },
#  name: "net/while/mul_4/x"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 0.20000000298023224
#      }
#    }
#  },
#  name: "net/while/add_4/y"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 0.5
#      }
#    }
#  },
#  name: "net/while/Const_2"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 0.0
#      }
#    }
#  },
#  name: "net/while/Const_3"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 1.0
#      }
#    }
#  },
#  name: "net/while/sub/x"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#        }
#        float_val: 1.0
#      }
#    }
#  },
#  name: "net/while/add_7/y"
#  op: "Const"
#  input: "^net/while/Identity"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "net/sub_1/y"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_INT32
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_INT32
#        tensor_shape {
#        }
#        int_val: 1
#      }
#    }
#  },
#  name: "dense_1/kernel"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#          dim {
#            size: 20
#          }
#          dim {
#            size: 1
#          }
#        }
#        tensor_content: "\030\216.>\000\216\323\276\263$\262>\232\027\002?\341\204Q\275\237\330\220\276\020i\267>\013\352\370>\213w\262\276\317\034\313>\224\264t\276\303\374\234\276\362\037\r\275\301\020y\276$*\022>z_\'\276,3\366\275|\272\352=\367\267\241>\376\300u>"
#      }
#    }
#  },
#  name: "dense_1/bias"
#  op: "Const"
#  attr {
#    key: "dtype"
#    value {
#      type: DT_FLOAT
#    }
#  }
#  attr {
#    key: "value"
#    value {
#      tensor {
#        dtype: DT_FLOAT
#        tensor_shape {
#          dim {
#            size: 1
#          }
#        }
#        float_val: 0.16249999403953552
#      }
#    }
#  }]

# %%
from tensorflow.python.framework import tensor_util

for n in wts:
    print( "Name of the node - %s" % n.name)
    print( "Value - " ) 
    tmp = tensor_util.MakeNdarray(n.attr['value'].tensor)
    print(tmp.shape)
# Out:
# Name of the node - net/kernel
# Value -
# (13, 60)
# Name of the node - net/recurrent_kernel
# Value -
# (20, 60)
# Name of the node - net/bias
# Value -
# (60,)
# Name of the node - net/strided_slice/stack
# Value -
# (2,)
# Name of the node - net/strided_slice/stack_1
# Value -
# (2,)
# Name of the node - net/strided_slice/stack_2
# Value -
# (2,)
# Name of the node - net/strided_slice_1/stack
# Value -
# (2,)
# Name of the node - net/strided_slice_1/stack_1
# Value -
# (2,)
# Name of the node - net/strided_slice_1/stack_2
# Value -
# (2,)
# Name of the node - net/strided_slice_2/stack
# Value -
# (2,)
# Name of the node - net/strided_slice_2/stack_1
# Value -
# (2,)
# Name of the node - net/strided_slice_2/stack_2
# Value -
# (2,)
# Name of the node - net/strided_slice_3/stack
# Value -
# (2,)
# Name of the node - net/strided_slice_3/stack_1
# Value -
# (2,)
# Name of the node - net/strided_slice_3/stack_2
# Value -
# (2,)
# Name of the node - net/strided_slice_4/stack
# Value -
# (2,)
# Name of the node - net/strided_slice_4/stack_1
# Value -
# (2,)
# Name of the node - net/strided_slice_4/stack_2
# Value -
# (2,)
# Name of the node - net/strided_slice_5/stack
# Value -
# (2,)
# Name of the node - net/strided_slice_5/stack_1
# Value -
# (2,)
# Name of the node - net/strided_slice_5/stack_2
# Value -
# (2,)
# Name of the node - net/strided_slice_6/stack
# Value -
# (1,)
# Name of the node - net/strided_slice_6/stack_1
# Value -
# (1,)
# Name of the node - net/strided_slice_6/stack_2
# Value -
# (1,)
# Name of the node - net/strided_slice_7/stack
# Value -
# (1,)
# Name of the node - net/strided_slice_7/stack_1
# Value -
# (1,)
# Name of the node - net/strided_slice_7/stack_2
# Value -
# (1,)
# Name of the node - net/strided_slice_8/stack
# Value -
# (1,)
# Name of the node - net/strided_slice_8/stack_1
# Value -
# (1,)
# Name of the node - net/strided_slice_8/stack_2
# Value -
# (1,)
# Name of the node - net/Sum/reduction_indices
# Value -
# (2,)
# Name of the node - net/ExpandDims/dim
# Value -
# ()
# Name of the node - net/Tile/multiples
# Value -
# (2,)
# Name of the node - net/transpose/perm
# Value -
# (3,)
# Name of the node - net/strided_slice_9/stack
# Value -
# (1,)
# Name of the node - net/strided_slice_9/stack_1
# Value -
# (1,)
# Name of the node - net/strided_slice_9/stack_2
# Value -
# (1,)
# Name of the node - net/strided_slice_10/stack
# Value -
# (1,)
# Name of the node - net/strided_slice_10/stack_1
# Value -
# (1,)
# Name of the node - net/strided_slice_10/stack_2
# Value -
# (1,)
# Name of the node - net/ones_like/Const
# Value -
# ()
# Name of the node - net/TensorArrayUnstack/strided_slice/stack
# Value -
# (1,)
# Name of the node - net/TensorArrayUnstack/strided_slice/stack_1
# Value -
# (1,)
# Name of the node - net/TensorArrayUnstack/strided_slice/stack_2
# Value -
# (1,)
# Name of the node - net/TensorArrayUnstack/range/start
# Value -
# ()
# Name of the node - net/TensorArrayUnstack/range/delta
# Value -
# ()
# Name of the node - net/time
# Value -
# ()
# Name of the node - net/while/maximum_iterations
# Value -
# ()
# Name of the node - net/while/iteration_counter
# Value -
# ()
# Name of the node - net/while/add/y
# Value -
# ()
# Name of the node - net/while/mul_3/x
# Value -
# ()
# Name of the node - net/while/add_2/y
# Value -
# ()
# Name of the node - net/while/Const
# Value -
# ()
# Name of the node - net/while/Const_1
# Value -
# ()
# Name of the node - net/while/mul_4/x
# Value -
# ()
# Name of the node - net/while/add_4/y
# Value -
# ()
# Name of the node - net/while/Const_2
# Value -
# ()
# Name of the node - net/while/Const_3
# Value -
# ()
# Name of the node - net/while/sub/x
# Value -
# ()
# Name of the node - net/while/add_7/y
# Value -
# ()
# Name of the node - net/sub_1/y
# Value -
# ()
# Name of the node - dense_1/kernel
# Value -
# (20, 1)
# Name of the node - dense_1/bias
# Value -
# (1,)
